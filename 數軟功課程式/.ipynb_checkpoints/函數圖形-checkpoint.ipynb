# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-4,4,10000)
y=np.tan(x)*np.sin(x)

# %%
y[y>1000]=np.inf
y[y<-1000]=-np.inf

# %%
plt.xkcd()

# %%
plt.plot(x,y)
