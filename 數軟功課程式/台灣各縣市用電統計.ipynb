# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('http://data.taipower.com.tw/opendata/apply/file/d007019/001.csv')

# %%
df
# Out:
#                              編號   縣市  A.住宅部門  B.服務業部門  C.機關用電(政府+包燈+大專院校)  \
# 0                             1  新北市    40.0     28.0                 3.0
# 1                             2  台北市    34.0     50.0                 9.0
# 2                             3  桃園市    16.0     13.0                 2.0
# 3                             4  台中市    19.0     18.0                 2.0
# 4                             5  台南市    14.0     10.0                 2.0
# 5                             6  高雄市    18.0     14.0                 3.0
# 6                             7  宜蘭縣    26.0     19.0                 4.0
# 7                             8  新竹縣    12.0      8.0                 1.0
# 8                             9  苗栗縣    14.0      8.0                 2.0
# 9                            10  彰化縣    21.0     13.0                 3.0
# 10                           11  南投縣    30.0     19.0                 5.0
# 11                           12  雲林縣    23.0     11.0                 3.0
# ...

# %%
df.shape
# Out:
# (23, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
# 編號                    23 non-null object
# 縣市                    22 non-null object
# A.住宅部門                22 non-null float64
# B.服務業部門               22 non-null float64
# C.機關用電(政府+包燈+大專院校)    22 non-null float64
# D.工業                  22 non-null float64
# E.其他                  22 non-null float64
# 合計(A~E)               22 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 1.5+ KB

# %%
df=df.drop(22)

# %%
df
# Out:
#     編號   縣市  A.住宅部門  B.服務業部門  C.機關用電(政府+包燈+大專院校)  D.工業  E.其他  合計(A~E)
# 0    1  新北市    40.0     28.0                 3.0  26.0   3.0    100.0
# 1    2  台北市    34.0     50.0                 9.0   3.0   4.0    100.0
# 2    3  桃園市    16.0     13.0                 2.0  66.0   3.0    100.0
# 3    4  台中市    19.0     18.0                 2.0  57.0   4.0    100.0
# 4    5  台南市    14.0     10.0                 2.0  71.0   3.0    100.0
# 5    6  高雄市    18.0     14.0                 3.0  55.0  10.0    100.0
# 6    7  宜蘭縣    26.0     19.0                 4.0  45.0   6.0    100.0
# 7    8  新竹縣    12.0      8.0                 1.0  77.0   2.0    100.0
# 8    9  苗栗縣    14.0      8.0                 2.0  73.0   3.0    100.0
# 9   10  彰化縣    21.0     13.0                 3.0  54.0   9.0    100.0
# 10  11  南投縣    30.0     19.0                 5.0  42.0   4.0    100.0
# 11  12  雲林縣    23.0     11.0                 3.0  53.0  10.0    100.0
# ...

# %%
df[['A.住宅部門','B.服務業部門','C.機關用電(政府+包燈+大專院校)','D.工業','E.其他']]
# Out:
#     A.住宅部門  B.服務業部門  C.機關用電(政府+包燈+大專院校)  D.工業  E.其他
# 0     40.0     28.0                 3.0  26.0   3.0
# 1     34.0     50.0                 9.0   3.0   4.0
# 2     16.0     13.0                 2.0  66.0   3.0
# 3     19.0     18.0                 2.0  57.0   4.0
# 4     14.0     10.0                 2.0  71.0   3.0
# 5     18.0     14.0                 3.0  55.0  10.0
# 6     26.0     19.0                 4.0  45.0   6.0
# 7     12.0      8.0                 1.0  77.0   2.0
# 8     14.0      8.0                 2.0  73.0   3.0
# 9     21.0     13.0                 3.0  54.0   9.0
# 10    30.0     19.0                 5.0  42.0   4.0
# 11    23.0     11.0                 3.0  53.0  10.0
# 12    31.0     14.0                 5.0  38.0  12.0
# 13    34.0     17.0                 5.0  26.0  18.0
# 14    41.0     30.0                 9.0  13.0   7.0
# 15    26.0     20.0                 7.0  41.0   6.0
# 16    49.0     29.0                 6.0  14.0   2.0
# ...

# %%
df['A.住宅部門'].plot()

# %%
df['B.服務業部門'].plot()

# %%
df['C.機關用電(政府+包燈+大專院校)'].plot()

# %%
df['D.工業'].plot()

# %%
df['E.其他'].plot()

# %%
mydata=np.random.randint(1,10,5).reshape(1,5)

# %%
df1 = pd.DataFrame(mydata)

# %%
df1
# Out:
#    0  1  2  3  4
# 0  9  4  1  1  5

# %%
df1.iloc[0,0]=int(df['A.住宅部門'].mean())
df1.iloc[0,1]=int(df['B.服務業部門'].mean())
df1.iloc[0,2]=int(df['C.機關用電(政府+包燈+大專院校)'].mean())
df1.iloc[0,3]=int(df['D.工業'].mean())
df1.iloc[0,4]=int(df['E.其他'].mean())
df1.columns = ['A.住宅部門','B.服務業部門','C.機關用電(政府+包燈+大專院校)','D.工業','E.其他']

# %%
df1
# Out:
#    A.住宅部門  B.服務業部門  C.機關用電(政府+包燈+大專院校)  D.工業  E.其他
# 0    27.0     20.0                 5.0  39.0   6.0
